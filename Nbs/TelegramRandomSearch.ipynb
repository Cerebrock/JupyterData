# %%
import re
import pandas as pd
import numpy as np

# %%
path = r'C:\Users\mgrinberg\Downloads\log.txt'
with open(path, 'r') as inp:
    content = inp.read()

# %%
content = re.sub("<class[\s\S]+?optimizers.(['.\w]+)'>", r"'\1'", content)

# %%
mods = re.findall('(\d+?),\s({.+})', content)

# %%
epochs = re.findall('Code\s(\d+?)\.\s(Epoch.+?);\n', content, flags=re.DOTALL)

# %%
dics = {}
for m in mods:
    code = m[0]
    arq = eval(m[1])
    hist = ''.join([e[1] for e in epochs if e[0] == code])
    try:
        arq['min_val_loss'] = min([float(n) for n in re.findall('val_loss: ([\d.]+?);', hist)])
    except ValueError:
        continue
    arq['max_val_coeff'] = max([float(n) for n in re.findall('val_coeff_determination: ([\-\d.]+?);', hist)])
    dics[code] = arq

# %%
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()

# %%
pd.options.display.max_columns = 100

# %%
df = pd.DataFrame.from_dict(dics, dtype='float64', orient='index')

# %%
df = df.sort_values(by='min_val_loss', ascending=True)

# %%
df.head()
# Out:
#          batch  deep  deep_input  deep_lstm  deep_output dense1_act  \
# 506483   512.0   1.0         1.0        1.0          0.0       tanh
# 17553    256.0   0.0         0.0        0.0          1.0       tanh
# 106714  1024.0   1.0         0.0        0.0          0.0       tanh
# 331345   128.0   1.0         1.0        0.0          1.0       tanh
# 538340   128.0   1.0         1.0        0.0          0.0       tanh
#
#         dense1_drop  dense1_n dense2_act  dense2_drop  dense2_n dense3_act  \
# 506483          0.0      96.0       relu          0.1      32.0       tanh
# 17553           0.0      32.0       relu          0.1      32.0       tanh
# 106714          0.0      96.0       relu          0.1      32.0       tanh
# 331345          0.0      96.0       relu          0.1      32.0       tanh
# 538340          0.0      96.0       relu          0.1      32.0       tanh
#
#         dense3_drop  dense3_n dense4_act  dense4_drop  dense4_n dense5_act  \
# 506483          0.5       8.0       relu     0.033333      96.0       tanh
# 17553           0.4      16.0       relu     0.033333      96.0       tanh
# 106714          0.1      32.0       relu     0.033333      32.0       tanh
# 331345          0.1      32.0       relu     0.033333      32.0       tanh
# 538340          0.2      32.0       relu     0.033333      96.0       tanh
#
#         dense5_drop  dense5_n dense6_act  dense6_drop  dense6_n dense7_act  \
# 506483          0.1      32.0       relu         0.06      32.0       tanh
# 17553           0.1      32.0       relu         0.06      32.0       tanh
# 106714          0.1      64.0       relu         0.18      32.0       tanh
# 331345          0.1      32.0       relu         0.24      32.0       tanh
# 538340          0.1      64.0       relu         0.24      32.0       tanh
#
#         dense7_drop  dense7_n dense8_act  dense8_drop  dense8_n  epochs  \
# 506483     0.033333      32.0       tanh          0.0      32.0    12.0
# 17553      0.033333      32.0       relu          0.0      64.0    40.0
# 106714     0.033333      32.0       relu          0.0      64.0    40.0
# 331345     0.033333      32.0       relu          0.0      96.0    40.0
# 538340     0.033333      32.0       relu          0.0      96.0    40.0
#
#         kernel_regularizer loss  lstm1_drop  lstm1_n  lstm2_drop  lstm2_n  \
# 506483                 0.0  mse         0.2     32.0    0.033333     32.0
# 17553                  0.0  mse         0.2      8.0    0.033333      8.0
# 106714                 0.0  mse         0.2     16.0    0.033333      8.0
# 331345                 0.0  mse         0.2     16.0    0.033333     32.0
# 538340                 0.0  mse         0.2     32.0    0.033333     16.0
#
#         lstm3_drop  lstm3_n       epsilon  amsgrad     lr optimizer  \
# 506483    0.066667     16.0  1.000000e-08      1.0  0.001      Adam
# 17553     0.066667     16.0  1.000000e-08      1.0  0.005      Adam
# 106714    0.066667     16.0  1.000000e-08      0.0  0.010      Adam
# 331345    0.066667     16.0  1.000000e-08      1.0  0.001      Adam
# 538340    0.066667     16.0  1.000000e-08      0.0  0.005      Adam
#
#         min_val_loss  max_val_coeff  residual dense9_act  dense9_drop  \
# 506483        0.1610         0.8399       1.0       relu          0.0
# 17553         0.1620         0.8076       NaN        NaN          NaN
# 106714        0.1656         0.8237       NaN        NaN          NaN
# 331345        0.1784         0.8215       NaN        NaN          NaN
# 538340        0.1821         0.8104       NaN        NaN          NaN
#
#         dense9_n
# 506483      96.0
# 17553        NaN
# 106714       NaN
# 331345       NaN
# 538340       NaN

# %%
df_cat = pd.get_dummies(df.select_dtypes('object'))

# %%
df_ = pd.merge(df_cat, df.select_dtypes(np.number), left_index=True, right_index=True)

# %%
# Chequear porque sin esto chispotea
df_ = df_.drop(df_.std()[(df_.std() < 0.01)].index, axis=1)

# %%
df_.corr('pearson').loc[:,['min_val_loss']].sort_values('min_val_loss').plot(kind='bar', figsize=(16,8))
plt.xticks(rotation=75);

# %%
df_.corr(method='spearman').loc[:,['min_val_loss']].sort_values('min_val_loss').plot(kind='bar', figsize=(16,8));

# %%
df_.corr(method='spearman').loc[:,['min_val_loss']].sort_values('min_val_loss')
# Out:
#                   min_val_loss
# max_val_coeff        -0.976923
# residual             -0.619780
# optimizer_Adam       -0.532512
# lstm3_n              -0.403330
# deep                 -0.277572
# batch                -0.248257
# lstm1_n              -0.116265
# dense9_n             -0.102869
# dense4_n             -0.086378
# epochs               -0.083239
# dense8_n             -0.077495
# dense9_act_relu      -0.075653
# dense8_act_relu      -0.064941
# amsgrad              -0.052889
# dense3_n             -0.039832
# dense1_n             -0.006934
# dense3_drop           0.028145
# deep_output           0.033309
# lstm2_n               0.040119
# dense5_n              0.052623
# dense8_act_tanh       0.064941
# dense6_drop           0.087226
# deep_input            0.088823
# dense9_act_tanh       0.181568
# optimizer_Nadam       0.198148
# deep_lstm             0.279369
# optimizer_Adamax      0.311376
# lr                    0.324121
# optimizer_SGD         0.348006
# dense1_drop           0.368144
# dense2_drop           0.396297
# min_val_loss          1.000000
