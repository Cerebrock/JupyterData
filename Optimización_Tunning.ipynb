# %% [markdown]
# ### Optimización

# %%
# !pip install cvxpy
# Out:
# Collecting cvxpy
#   Downloading https://files.pythonhosted.org/packages/c2/d4/123077905277c2222b104be90012b633911cce7b7b9f38976763c3998c9f/cvxpy-1.0.6.tar.gz (893kB)
#     100% |████████████████████████████████| 901kB 10.2MB/s
# Collecting osqp (from cvxpy)
#   Downloading https://files.pythonhosted.org/packages/60/c3/929cf43fbfec0d68742760e8357f9f5f68fb129961d8278f29f2a7c19088/osqp-0.3.1-cp36-cp36m-manylinux1_x86_64.whl (137kB)
#     100% |████████████████████████████████| 143kB 11.9MB/s
# Collecting ecos>=2 (from cvxpy)
#   Downloading https://files.pythonhosted.org/packages/b6/b4/988b15513b13e8ea2eac65e97d84221ac515a735a93f046e2a2a3d7863fc/ecos-2.0.5.tar.gz (114kB)
#     100% |████████████████████████████████| 122kB 21.7MB/s
# Collecting scs>=1.1.3 (from cvxpy)
#   Downloading https://files.pythonhosted.org/packages/b3/fd/6e01c4f4a69fcc6c3db130ba55572089e78e77ea8c0921a679f9da1ec04c/scs-2.0.2.tar.gz (133kB)
#     100% |████████████████████████████████| 143kB 14.6MB/s
# Collecting multiprocess (from cvxpy)
#   Downloading https://files.pythonhosted.org/packages/65/03/bd8ac79948049b5a0f7ee5f2642f76dbb2d9cb83cc5433dfb2112f89d69a/multiprocess-0.70.5.zip (1.5MB)
#     100% |████████████████████████████████| 1.5MB 12.9MB/s
# Collecting fastcache (from cvxpy)
#   Downloading https://files.pythonhosted.org/packages/fb/98/93f2d36738868e8dd5a8dbfc918169b24658f63e5fa041fe000c22ae4f8b/fastcache-1.0.2.tar.gz
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from cvxpy) (1.11.0)
# Requirement already satisfied: toolz in /usr/local/lib/python3.6/dist-packages (from cvxpy) (0.9.0)
# Requirement already satisfied: numpy>=1.14 in /usr/local/lib/python3.6/dist-packages (from cvxpy) (1.14.3)
# Requirement already satisfied: scipy>=0.19 in /usr/local/lib/python3.6/dist-packages (from cvxpy) (0.19.1)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from osqp->cvxpy) (0.16.0)
# Collecting dill>=0.2.6 (from multiprocess->cvxpy)
#   Downloading https://files.pythonhosted.org/packages/91/a0/19d4d31dee064fc553ae01263b5c55e7fb93daff03a69debbedee647c5a0/dill-0.2.7.1.tar.gz (64kB)
#     100% |████████████████████████████████| 71kB 21.5MB/s
# Building wheels for collected packages: cvxpy, ecos, scs, multiprocess, fastcache, dill
# /
# done
#   Stored in directory: /content/.cache/pip/wheels/6d/78/df/bd8d02476516cf184699705248d001a806c220add5e3994caa
# done
#   Stored in directory: /content/.cache/pip/wheels/50/91/1b/568de3c087b3399b03d130e71b1fd048ec072c45f72b6b6e9a
# done
#   Stored in directory: /content/.cache/pip/wheels/ff/f0/aa/530ccd478d7d9900b4e9ef5bc5a39e895ce110bed3d3ac653e
# done
#   Stored in directory: /content/.cache/pip/wheels/85/44/92/7635fa709a1e88a4dca84eba3d1566fc0e2b001d4d84f40d35
# done
#   Stored in directory: /content/.cache/pip/wheels/b7/90/c0/da92ac52d188d9ebca577044e89a14d0e6ff333c1bcd1ebc14
# done
#   Stored in directory: /content/.cache/pip/wheels/99/c4/ed/1b64d2d5809e60d5a3685530432f6159d6a9959739facb61f2
# Successfully built cvxpy ecos scs multiprocess fastcache dill
# Installing collected packages: osqp, ecos, scs, dill, multiprocess, fastcache, cvxpy

# %%
import cvxpy as cp
import numpy as np
import time
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-25a85a968550> in <module>()
# ----> 1 import cvxpy as cp
#       2 import numpy as np
#       3 import time
#
# ModuleNotFoundError: No module named 'cvxpy'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# $$\large{ argmin_{x} | ( \mathbf{q} - \mathbf{q_{0}} ) \oslash  \mathbf{q_{0}} |}
# \\subject\:to: \quad \large{\\ Rq = b \;, \\ Mq \leq d} $$

# %%
def evaluate_sol(x):
    """Recieves solution vector and computes difference w.r.t PRESUPUESTO and HISTORICO"""

    global diffs_prod, diffs_hist
    assert np.all(x > 0)
    
    diffs_prod = [sum([x[n] for n in Q[i,:,:].flatten()]) - PRES[i] for i in range(p)]
    
    diffs_hist = [x[n] - HIST[n] for n in range(t)]
    
    return np.around([np.sum(np.abs(diffs_prod)), np.max(diffs_prod), np.min(diffs_prod), np.mean(diffs_prod), 
                      np.std(diffs_prod), np.mean(diffs_hist), np.std(diffs_hist)], 4)

# %%
def solve(p, d, c, PRES, HIST, solver = 'SCS', o = None, _ = 1):
    # Vamos a optimizar para producto, depósito y canal
    # Hay aprox 139 productos, 17 depósitos y 3 canales
    
    # Vector con p*d*c variables
    global x, Q

    cons = []

    # todo elemento es mayor a 0
    for e in x:
        cons.append(e >= 0)

    # para el producto i:
    # sum(Q_idc) <= PRES[i]
    if _:
        for i in range(p):
            cons.append(sum([x[n] for n in Q[i,:,:].flatten()]) <= PRES[i])
    else:
        for i in range(p):
            cons.append(sum([x[n] for n in Q[i,:,:].flatten()]) == PRES[i])
    
    # funcion objetivo, minimizar la diferencia con el mes anterior (HIST) 
    # y maximizar la asignación de productos 

    if o:
        obj = cp.Minimize(o)
    else: 
        obj = cp.Minimize(cp.sum_squares(x - HIST) - sum(x))

    prob = cp.Problem(obj, cons)
    
    t0 = time.time()
    sol = prob.solve('SCS')
    t1 = time.time()
    
    S = np.fromiter(x.value, dtype = 'float32')
    
    _ = evaluate_sol(S)
    
    return list(_) + [np.around(t1-t0), prob.status]

# %%
# %%time
np.random.seed(101)
p, d, c = 139, 17, 3
t = p*d*c
PRES = np.random.randint(10000, 20000, size = p)
HIST = np.floor(np.random.normal(PRES.sum()//t, size = t))

# Tensor con una var para cada producto+deposito+canal
Q = np.arange(t).reshape((p,d,c))
x = cp.Variable(t)


solvers =  ['CVXOPT', 'GLPK', 'GLPK_MI', 'SCS', 'LS']

objs = [cp.sum_squares(x - HIST), cp.sum_squares(x - HIST) - sum(x), cp.sum_squares(x - HIST) - 2*sum(x), 
        cp.sum_squares(x - HIST) - 3*sum(x), cp.sum_squares(x - HIST) - cp.sum_squares(x)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-026c83e87be2> in <module>()
# ----> 1 np.random.seed(101)
#       2 p, d, c = 139, 17, 14
#       3 t = p*d*c
#       4 PRES = np.random.randint(10000, 20000, size = p)
#       5 HIST = np.floor(np.random.normal(PRES.sum()//t, size = t))
#
# NameError: name 'np' is not defined

# %%
# %%time

d = {}
for m in solvers:
    for j in range(len(objs)):
        for z in [0, 1]:
            try:
                d[(m, str(j), ['==', '<='][z])] = solve(p, d, c, PRES, HIST, m, objs[j], z)
            except:
                d[(m, str(j), ['==', '<='][z])] = None

# %%
import pickle

path = input('out')
with open(path + '.pickle', 'wb') as handle:
    pickle.dump(d, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# outa
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-40b917eb8b42> in <module>()
#       3 path = input('out')
#       4 with open(path + '.pickle', 'wb') as handle:
# ----> 5     pickle.dump(d, handle, protocol=pickle.HIGHEST_PROTOCOL)
#
# NameError: name 'd' is not defined

# %%
import pandas as pd

for k in d:
    d[str(k)] = d[k]
    del d[k]
df = pd.DataFrame.from_dict(d)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-42-e5d9217b29d7> in <module>()
# ----> 1 for k in d:
#       2     d[str(k)] = d[k]
#       3     del d[k]
#
# RuntimeError: dictionary changed size during iteration

# %%
s = solve(p, d, c, PRES, HIST)

# %%
df
# Out:
#           (SCS, 3, ==) (SCS, 3, <=) (SCS, 4, ==) (SCS, 4, <=)  \
# ΔPRESsum          None         None         None         None
# ΔPRESmax          None         None         None         None
# ΔPRESmin          None         None         None         None
# ΔPRESmean         None         None         None         None
# ΔPRESstd          None         None         None         None
# ΔHISTmean         None         None         None         None
# ΔHISTstd          None         None         None         None
# t                 None         None         None         None
# status            None         None         None         None
#
#                   (LS, 0, ==)         (LS, 0, <=)         (LS, 1, ==)  \
# ΔPRESsum              2769.46              148865             1002.66
# ΔPRESmax              32.6655             -3.3467              5.0683
# ΔPRESmin              -45.921            -4595.31            -16.7841
# ΔPRESmean             -6.6363            -1070.97             -5.8607
# ΔPRESstd              22.3782             1502.37              6.2227
# ΔHISTmean              1.0071            -19.8622              1.0223
# ΔHISTstd              55.5141             32.6094             55.1974
# t                          42                  42                  47
# status     optimal_inaccurate  optimal_inaccurate  optimal_inaccurate
#
#                   (LS, 1, <=)         (LS, 2, ==)         (LS, 2, <=)  \
# ΔPRESsum              67417.4             687.274             8971.06
# ΔPRESmax              -2.4308              0.4196              -1.548
# ΔPRESmin             -3044.69            -10.2376            -857.191
# ΔPRESmean            -485.017             -4.9102              -64.54
# ΔPRESstd              939.804              3.0349             186.104
# ΔHISTmean             -8.3729               1.041             -0.1282
# ΔHISTstd              42.7819             55.1348             53.1968
# t                          47                  46                  47
# status     optimal_inaccurate  optimal_inaccurate  optimal_inaccurate
#
#                   ...         ('GLPK_MI', '3', '==') ('GLPK_MI', '3', '<=')  \
# ΔPRESsum          ...                           None                   None
# ΔPRESmax          ...                           None                   None
# ΔPRESmin          ...                           None                   None
# ΔPRESmean         ...                           None                   None
# ΔPRESstd          ...                           None                   None
# ΔHISTmean         ...                           None                   None
# ΔHISTstd          ...                           None                   None
# t                 ...                           None                   None
# status            ...                           None                   None
#
#           ('GLPK_MI', '4', '==') ('GLPK_MI', '4', '<=')  ('SCS', '0', '==')  \
# ΔPRESsum                    None                   None             2769.46
# ΔPRESmax                    None                   None             32.6655
# ΔPRESmin                    None                   None             -45.921
# ΔPRESmean                   None                   None             -6.6363
# ΔPRESstd                    None                   None             22.3782
# ΔHISTmean                   None                   None              1.0071
# ΔHISTstd                    None                   None             55.5141
# t                           None                   None                  42
# status                      None                   None  optimal_inaccurate
#
#            ('SCS', '0', '<=')  ('SCS', '1', '==')  ('SCS', '1', '<=')  \
# ΔPRESsum               148865             1002.66             67417.4
# ΔPRESmax              -3.3467              5.0683             -2.4308
# ΔPRESmin             -4595.31            -16.7841            -3044.69
# ΔPRESmean            -1070.97             -5.8607            -485.017
# ΔPRESstd              1502.37              6.2227             939.804
# ΔHISTmean            -19.8622              1.0223             -8.3729
# ΔHISTstd              32.6094             55.1974             42.7819
# t                          41                  45                  45
# status     optimal_inaccurate  optimal_inaccurate  optimal_inaccurate
#
#            ('SCS', '2', '==')  ('SCS', '2', '<=')
# ΔPRESsum              687.274             8971.06
# ΔPRESmax               0.4196              -1.548
# ΔPRESmin             -10.2376            -857.191
# ΔPRESmean             -4.9102              -64.54
# ΔPRESstd               3.0349             186.104
# ΔHISTmean               1.041             -0.1282
# ΔHISTstd              55.1348             53.1968
# t                          46                  46
# status     optimal_inaccurate  optimal_inaccurate
#
# [9 rows x 49 columns]

# %%
df.index = 'ΔPRESsum ΔPRESmax  ΔPRESmin  ΔPRESmean  ΔPRESstd  ΔHISTmean  ΔHISTstd  t status'.split()

# %%
df.iloc[3, 4]

# %%
df.dropna(axis = 1)[:, df.iloc[3]]
# Out:
#                   (LS, 0, ==)         (LS, 0, <=)         (LS, 1, ==)  \
# ΔPRESsum              2769.46              148865             1002.66
# ΔPRESmax              32.6655             -3.3467              5.0683
# ΔPRESmin              -45.921            -4595.31            -16.7841
# ΔPRESmean             -6.6363            -1070.97             -5.8607
# ΔPRESstd              22.3782             1502.37              6.2227
# ΔHISTmean              1.0071            -19.8622              1.0223
# ΔHISTstd              55.5141             32.6094             55.1974
# t                          42                  42                  47
# status     optimal_inaccurate  optimal_inaccurate  optimal_inaccurate
#
#                   (LS, 1, <=)         (LS, 2, ==)         (LS, 2, <=)  \
# ΔPRESsum              67417.4             687.274             8971.06
# ΔPRESmax              -2.4308              0.4196              -1.548
# ΔPRESmin             -3044.69            -10.2376            -857.191
# ΔPRESmean            -485.017             -4.9102              -64.54
# ΔPRESstd              939.804              3.0349             186.104
# ΔHISTmean             -8.3729               1.041             -0.1282
# ΔHISTstd              42.7819             55.1348             53.1968
# t                          47                  46                  47
# status     optimal_inaccurate  optimal_inaccurate  optimal_inaccurate
#
#           ('CVXOPT', '0', '==') ('CVXOPT', '0', '<=') ('CVXOPT', '1', '==')  \
# ΔPRESsum                2769.46                148865               1002.66
# ΔPRESmax                32.6655               -3.3467                5.0683
# ΔPRESmin                -45.921              -4595.31              -16.7841
# ΔPRESmean               -6.6363              -1070.97               -5.8607
# ΔPRESstd                22.3782               1502.37                6.2227
# ΔHISTmean                1.0071              -19.8622                1.0223
# ΔHISTstd                55.5141               32.6094               55.1974
# t                            46                    49                    61
# status       optimal_inaccurate    optimal_inaccurate    optimal_inaccurate
#
#           ('CVXOPT', '1', '<=')         ...         ('GLPK_MI', '1', '==')  \
# ΔPRESsum                67417.4         ...                        1002.66
# ΔPRESmax                -2.4308         ...                         5.0683
# ΔPRESmin               -3044.69         ...                       -16.7841
# ΔPRESmean              -485.017         ...                        -5.8607
# ΔPRESstd                939.804         ...                         6.2227
# ΔHISTmean               -8.3729         ...                         1.0223
# ΔHISTstd                42.7819         ...                        55.1974
# t                            61         ...                             46
# status       optimal_inaccurate         ...             optimal_inaccurate
#
#           ('GLPK_MI', '1', '<=') ('GLPK_MI', '2', '==')  \
# ΔPRESsum                 67417.4                687.274
# ΔPRESmax                 -2.4308                 0.4196
# ΔPRESmin                -3044.69               -10.2376
# ΔPRESmean               -485.017                -4.9102
# ΔPRESstd                 939.804                 3.0349
# ΔHISTmean                -8.3729                  1.041
# ΔHISTstd                 42.7819                55.1348
# t                             43                     45
# status        optimal_inaccurate     optimal_inaccurate
#
#           ('GLPK_MI', '2', '<=')  ('SCS', '0', '==')  ('SCS', '0', '<=')  \
# ΔPRESsum                 8971.06             2769.46              148865
# ΔPRESmax                  -1.548             32.6655             -3.3467
# ΔPRESmin                -857.191             -45.921            -4595.31
# ΔPRESmean                 -64.54             -6.6363            -1070.97
# ΔPRESstd                 186.104             22.3782             1502.37
# ΔHISTmean                -0.1282              1.0071            -19.8622
# ΔHISTstd                 53.1968             55.5141             32.6094
# t                             45                  42                  41
# status        optimal_inaccurate  optimal_inaccurate  optimal_inaccurate
#
#            ('SCS', '1', '==')  ('SCS', '1', '<=')  ('SCS', '2', '==')  \
# ΔPRESsum              1002.66             67417.4             687.274
# ΔPRESmax               5.0683             -2.4308              0.4196
# ΔPRESmin             -16.7841            -3044.69            -10.2376
# ΔPRESmean             -5.8607            -485.017             -4.9102
# ΔPRESstd               6.2227             939.804              3.0349
# ΔHISTmean              1.0223             -8.3729               1.041
# ΔHISTstd              55.1974             42.7819             55.1348
# t                          45                  45                  46
# status     optimal_inaccurate  optimal_inaccurate  optimal_inaccurate
#
#            ('SCS', '2', '<=')
# ΔPRESsum              8971.06
# ΔPRESmax               -1.548
# ΔPRESmin             -857.191
# ΔPRESmean              -64.54
# ΔPRESstd              186.104
# ΔHISTmean             -0.1282
# ΔHISTstd              53.1968
# t                          46
# status     optimal_inaccurate
#
# [9 rows x 29 columns]
